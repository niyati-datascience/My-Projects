# %% [markdown]
# ## CRITICAL ANALYSIS TASK

# %% [markdown]
# ###### 1)Problem :Selection of Features by the mode of Correlation negative or positive

# %% [markdown]
# The choice to eliminate features based on the relationship between the features and their target variable, ‘credit.policy’, can be viewed as subjective and depends on the context of the problem. However, the relationship between features and target variable does not necessarily mean that it is causal or useful for model training.
#
# While it may be prudent to focus on highly correlated features, ignoring features based solely on their correlation may result in the loss of valuable information.

# %% [markdown]
# ###### Remedy:
# Utilize techniques such as recursive feature elimination which works by repeating the process of removing the least significant features from a predictive model according to their coefficient values, and then repeating the process with the remaining features until the required number of features is achieved.

# %%
from IPython.display import Image
Image(filename='1car.png',width = "600",height = "300")

# %% [markdown]
# ###### 2)Problem:Sorting data set in ascending order and then splitting it.

# %% [markdown]
# The problem in this case relates to the way in which the dataset is split down into training data sets, validation data sets, and test data sets. The classification of the records solely on the basis of the ‘credit.policy’ feature, in ascending order, may introduce an element of bias and may impede the model’s generalizability. This approach is based on the assumption that the records that are sorted by the credit.policy feature represent the entirety of the dataset, which is not necessarily the case.

# %% [markdown]
# ###### Remedy:
# Randomly split the data into 80:10:10 without defining the order

# %%
from IPython.display import Image
Image(filename='2car.png',width = "600",height = "300")

# %% [markdown]
# ###### 3) Problem:Cross Value is Confusing

# %%
from IPython.display import Image
Image(filename='3car.png',width = "600",height = "300")

# %% [markdown]
# ###### Remedy:
# _cv=9 then quoted comment should be "Function to perform 9 Folds Cross-Validation"or a bigger method is to change whole code according to 5 fold i.e _cv=5 and select folds from 1 fold to 5 folds rather than 9 folds

# %% [markdown]
# ###### 4)Problem: Adjusting mean value in null value

# %% [markdown]
# If the dataset contains missing values and the average value is not suitable for imputing the missing values due to biases. Applying the average value to the missing values may affect the data distribution and model performance.

# %% [markdown]
# ###### Remedy:
# In cases where the data is subject to outliers or the distribution is abnormal, other imputation methods may be applicable, including imputation with median, mode, and advanced imputation techniques such as K-nearest neighbor (KNN) and multiple imputation. It is important to comprehend the nature of the dataset and select the method of imputation that preserves the data integrity.A normality check can be done by constructing a histogram.
# Code:

# %%
from IPython.display import Image
Image(filename='4 car.png',width = "600",height = "300")

# %% [markdown]
# ###### 5)Problem: Imbalanced class distribution

# %%
from IPython.display import Image
Image(filename='5car.png',width = "600",height = "300")

# %% [markdown]
# It is essential to analyze the class distribution of the target variable, credit.policy, as it is composed of only two values: 0 and 1. There are 7710 instances of 1, and 1868 instances of 0. If the class distribution is significantly imbalanced, it can have a significant impact on the predictive performance of the model. In particular, if the majority of instances belong to one class, the model will tend to favor that class, leading to poor performance of the minority class when compared to the majority class. Therefore, it is necessary to address this issue during model training in order to guarantee that the model accurately predicts both classes.

# %% [markdown]
# ###### Remedy
# Imbalanced data can be managed through a variety of methods, including resampling techniques or collecting more data.

# %% [markdown]
# ###### 6)Problem: overfitting in  decision matrix

# %% [markdown]
# The critical problem appears to be a discrepancy between 95.59% of the training success rate and 32.92% of the test success rate. The decision tree model appears to be equipped with the most optimal grid search parameters, however, the test performance is significantly inferior to the train performance.This discrepancy suggests that a decision tree classifier may overfit the training data, leading to poor generalization to non-observed data.

# %% [markdown]
# ###### Remedy:
# Once all the above problem are solved accuracy may get improved because training and test set doesn't contain the negative correlated features as well as the dataset was ordered in a ascending oder that cause biasness towards dataset and many more problems
